# %%
capitals = {'argentina':'buenos aires', 'chile':'santiago', 'peru':'lima', 'colombia':'bogota'}

# %%
print(type(capitals))
# Out:
# <class 'dict'>

# %%
capitals[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-dd402b96e274> in <module>
# ----> 1 capitals[1]
#
# KeyError: 1

# %%
capitals['argentina']
# Out:
# 'buenos aires'

# %%
marvel = {'ironman':'suit', 'captain':['shield', 'hammer'], 'thor':'hammer'}

# %%
marvel['ironman']
# Out:
# 'suit'

# %%
marvel['captain']
# Out:
# ['shield', 'hammer']

# %%
avengers = {'ironman':'suit', 'captain':['shield', 'hammer'], 'thor':'hammer'}

# %%
marvel = {'magneto':'metal magic', 'wolverine':'claws', 'avengers':avengers}

# %%
marvel['magneto']
# Out:
# 'metal magic'

# %%
marvel
# Out:
# {'magneto': 'metal magic',
#  'wolverine': 'claws',
#  'avengers': {'ironman': 'suit',
#   'captain': ['shield', 'hammer'],
#   'thor': 'hammer'}}

# %%
len(marvel)
# Out:
# 3

# %%
marvel['avengers']
# Out:
# {'ironman': 'suit', 'captain': ['shield', 'hammer'], 'thor': 'hammer'}

# %%
marvel['avengers']['captain']
# Out:
# ['shield', 'hammer']

# %%
marvel['avengers']['captain'][0]
# Out:
# 'shield'

# %%
marvel['avengers']['captain'][0][2]
# Out:
# 'i'

# %%
capitals = {'argentina':'buenos aires', 'chile':'santiago', 'peru':'lima', 'colombia':'bogota'}

# %%
capitals ['peru'] = 'LIMA'

# %%
capitals
# Out:
# {'argentina': 'buenos aires',
#  'chile': 'santiago',
#  'peru': 'LIMA',
#  'colombia': 'bogota'}

# %%
capitals['venezuela']= 'caracas'

# %%
capitals
# Out:
# {'argentina': 'buenos aires',
#  'chile': 'santiago',
#  'peru': 'LIMA',
#  'colombia': 'bogota',
#  'venezuela': 'caracas'}

# %%
# pandas

# %%
import pandas as pd

# %%
dfa = pd.read_excel('five.xlsx')

# %%
dfa
# Out:
#                                           Table                 Breakdown  \
# 0                      01 Total R&D Expenditure        01_R&D Expenditure
# 1                      01 Total R&D Expenditure        01_R&D Expenditure
# 2                      01 Total R&D Expenditure        01_R&D Expenditure
# 3                      01 Total R&D Expenditure        01_R&D Expenditure
# 4                      01 Total R&D Expenditure        01_R&D Expenditure
# ..                                          ...                       ...
# 895  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 896  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 897  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 898  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 899  15 Broad purpose of research by sub-sector  16_Total Business Sector
#
#           Secondary_Breakdown  Year Value        Unit      cum
# ...

# %%
dict(dfa['Breakdown'])
# Out:
# {0: '01_R&D Expenditure',
#  1: '01_R&D Expenditure',
#  2: '01_R&D Expenditure',
#  3: '01_R&D Expenditure',
#  4: '01_R&D Expenditure',
#  5: '01_R&D Expenditure',
#  6: '01_R&D Expenditure',
#  7: '01_R&D Expenditure',
#  8: '01_R&D Expenditure',
#  9: '01_R&D Expenditure',
#  10: '01_R&D Expenditure',
#  11: '01_R&D Expenditure',
#  12: '01_R&D Expenditure',
#  13: '01_R&D Expenditure',
#  14: '01_R&D Expenditure',
#  15: '01_R&D Expenditure',
#  16: '01_R&D Expenditure',
#  17: '01_R&D Expenditure',
#  18: '01_R&D Expenditure',
#  19: '01_R&D Expenditure',
#  20: '02_R&D Exp as a proportion of GDP',
#  21: '02_R&D Exp as a proportion of GDP',
#  22: '02_R&D Exp as a proportion of GDP',
#  23: '02_R&D Exp as a proportion of GDP',
#  24: '02_R&D Exp as a proportion of GDP',
#  25: '02_R&D Exp as a proportion of GDP',
#  26: '02_R&D Exp as a proportion of GDP',
#  27: '02_R&D Exp as a proportion of GDP',
#  28: '02_R&D Exp as a proportion of GDP',
# ...

# %%
capitals.keys()
# Out:
# dict_keys(['argentina', 'chile', 'peru', 'colombia', 'venezuela'])

# %%
list(capitals.keys())
# Out:
# ['argentina', 'chile', 'peru', 'colombia', 'venezuela']

# %%
list(capitals.values())
# Out:
# ['buenos aires', 'santiago', 'LIMA', 'bogota', 'caracas']

# %%
list(avengers.values())
# Out:
# ['suit', ['shield', 'hammer'], 'hammer']
